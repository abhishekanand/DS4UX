# %% [markdown]
# # Building permits by neighborhood
#
# In this demo, we'll walk through the process of downloading and processing a dataset, using the concepts we learned today:
# - `try` and `except`
# - `time.sleep()`
# - `dateutil.parser`
# - `datetime.datetime`
# - writing your own functions

# %%
import requests
import json
# define the endpoint for the api request
bp_api_endpoint = "https://data.seattle.gov/resource/mags-97de.json?"

# %%
#set parameters that we are passing to the API, to filter the data we want
bp_api_params = {
"$select" : "application_permit_number, action_type, address, category, value, issue_date, latitude, longitude",
"$where" : "(action_type='NEW' OR action_type='ADD/ALT') AND category='MULTIFAMILY' AND (status='Permit Issued' OR status='Permit Finaled' OR status='Permit Closed')",
"$order" : "issue_date DESC",
"$limit" : "10000",
}

# %%
#request the data from data.seattle.gov API and store it as a Python dictionary
bp_api_req = requests.get(bp_api_endpoint, params=bp_api_params)
bp_api_data = bp_api_req.json()
print(bp_api_data[0])
print(len(bp_api_data))
# Out:
# {'longitude': '-122.35414135', 'value': '311000', 'application_permit_number': '6118877', 'action_type': 'NEW', 'address': '8725 PHINNEY AVE N', 'category': 'MULTIFAMILY', 'latitude': '47.69321735'}
# 2744

# %%
#save the JSON object as a file as well, just in case we lose access to the API later
with open('multifamily_permits_2010-2016.json', 'w') as json_outfile:
    json.dump(bp_api_data, json_outfile)

# %%
def queryGmapsAPI(query_params, query_type):
    if query_type == "latlng":
        gmaps_api_params = {'latlng' : query_params}
    elif query_type == "address":
        gmaps_api_params = {'address' : query_params}
    else:
        return "unrecognized query type. Please use 'latlng' or 'address'"
#     q_string = "http://maps.googleapis.com/maps/api/geocode/json?" + query_type + "=" + query_params
#     print(q_string)
    gmaps_api_req = requests.get("http://maps.googleapis.com/maps/api/geocode/json", params=gmaps_api_params)
    gmaps_api_data = gmaps_api_req.json()

    return gmaps_api_data

# %%
import time
with open("multifamily_permits_2010-2016.json") as json_infile:
    bp_api_data = json.load(json_infile)
# print(json.dumps(bp_api_data, indent=2))

# %%
counter = 0
permits_with_neighborhoods = 0
permits_by_neighborhood = {}
skipped_records = []

for x in bp_api_data:
    if counter < 10:
        print(counter)
        counter+= 1

        try:
            loc_params = x['latitude'] + "," + x["longitude"]
            loc_type = "latlng"
            loc_data = queryGmapsAPI(loc_params, loc_type)
        except KeyError:
            print("Couldn't find lat/lng for %s, trying query again with address" % (x['application_permit_number']))
            loc_params = x['address'] + "Seattle WA"
            loc_type = "address"            
            loc_data = queryGmapsAPI(loc_params, loc_type)

        if loc_data['status']:
            if loc_data['status'] == "OK":
                neighborhood = loc_data['results'][0]['address_components'][2]['long_name']
                permits_with_neighborhoods += 1        
                print("Found neighborhood for %s: %s" % (x['application_permit_number'], neighborhood))
                time.sleep(0.2)
            elif loc_data['status'] == "OVER_QUERY_LIMIT":                
                print("Could not get neighborhood data for record %s: %s" 
                      % (x['application_permit_number'], loc_data['status']))
                print(loc_data)
                skipped_records.append(x)
                time.sleep(0.2)
                continue
            elif loc_data['status'] == "ZERO_RESULTS":
                print("unrecognized location %s for record %s" 
                      % (x['address'], x['application_permit_number']))
                skipped_records.append(x)
                time.sleep(0.2)  
                continue
            else:
                print("unrecognized status in API response: %s" 
                      % (loc_data['status']))
                skipped_records.append(x)
                time.sleep(0.2)
                continue
        else:
            print(loc_data)
            continue

        if neighborhood in permits_by_neighborhood:
            permits_by_neighborhood[neighborhood] += 1
        else:
            permits_by_neighborhood[neighborhood] = 1
    else:
        break  

print("%d records were analyzed" % (counter))
print("/n")
print("Neighborhoods were identified for %d records" % (permits_with_neighborhoods))
print("/n")
print("%d records were skipped" % (len(skipped_records)))
print("/n")
print("Here's your data!")
print(json.dumps(permits_by_neighborhood, indent = 2))
# Out:
# 0
# Found neighborhood for 6118877: Greenwood
# 1
# Could not get neighborhood data for record 6118890: OVER_QUERY_LIMIT
# {'status': 'OVER_QUERY_LIMIT', 'error_message': 'You have exceeded your daily request quota for this API. We recommend registering for a key at the Google Developers Console: https://console.developers.google.com/apis/credentials?project=_', 'results': []}
# 2
# Could not get neighborhood data for record 6526311: OVER_QUERY_LIMIT
# {'status': 'OVER_QUERY_LIMIT', 'error_message': 'You have exceeded your daily request quota for this API. We recommend registering for a key at the Google Developers Console: https://console.developers.google.com/apis/credentials?project=_', 'results': []}
# 3
# Found neighborhood for 6494431: Capitol Hill
# 4
# Could not get neighborhood data for record 6533460: OVER_QUERY_LIMIT
# {'status': 'OVER_QUERY_LIMIT', 'error_message': 'You have exceeded your daily request quota for this API. We recommend registering for a key at the Google Developers Console: https://console.developers.google.com/apis/credentials?project=_', 'results': []}
# 5
# Could not get neighborhood data for record 6533460: OVER_QUERY_LIMIT
# {'status': 'OVER_QUERY_LIMIT', 'error_message': 'You have exceeded your daily request quota for this API. We recommend registering for a key at the Google Developers Console: https://console.developers.google.com/apis/credentials?project=_', 'results': []}
# 6
# Could not get neighborhood data for record 6517579: OVER_QUERY_LIMIT
# {'status': 'OVER_QUERY_LIMIT', 'error_message': 'You have exceeded your daily request quota for this API. We recommend registering for a key at the Google Developers Console: https://console.developers.google.com/apis/credentials?project=_', 'results': []}
# 7
# Could not get neighborhood data for record 6532847: OVER_QUERY_LIMIT
# {'status': 'OVER_QUERY_LIMIT', 'error_message': 'You have exceeded your daily request quota for this API. We recommend registering for a key at the Google Developers Console: https://console.developers.google.com/apis/credentials?project=_', 'results': []}
# 8
# Could not get neighborhood data for record 6532847: OVER_QUERY_LIMIT
# {'status': 'OVER_QUERY_LIMIT', 'error_message': 'You have exceeded your daily request quota for this API. We recommend registering for a key at the Google Developers Console: https://console.developers.google.com/apis/credentials?project=_', 'results': []}
# 9
# Could not get neighborhood data for record 6483012: OVER_QUERY_LIMIT
# {'status': 'OVER_QUERY_LIMIT', 'error_message': 'You have exceeded your daily request quota for this API. We recommend registering for a key at the Google Developers Console: https://console.developers.google.com/apis/credentials?project=_', 'results': []}
# 10 records were analyzed
# /n
# Neighborhoods were identified for 2 records
# /n
# 8 records were skipped
# /n
# Here's your data!
# {
#   "Capitol Hill": 1,
#   "Greenwood": 1
# }

# %%
with open("multifamily_permits_2010-2016.json") as json_infile:
    bp_api_data = json.load(json_infile)

print(json.dumps(bp_api_data, indent=2))
# Out:
# [
#   {
#     "longitude": "-122.37549243",
#     "value": "104821",
#     "issue_date": "2016-05-13T00:00:00",
#     "application_permit_number": "6526311",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63886596",
#     "category": "MULTIFAMILY",
#     "address": "1404 W BOSTON ST"
#   },
#   {
#     "longitude": "-122.26612732",
#     "value": "75000",
#     "issue_date": "2016-05-12T00:00:00",
#     "application_permit_number": "6533460",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67450527",
#     "category": "MULTIFAMILY",
#     "address": "6323 SAND POINT WAY NE"
#   },
#   {
#     "longitude": "-122.26612732",
#     "value": "75000",
#     "issue_date": "2016-05-12T00:00:00",
#     "application_permit_number": "6533460",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67450527",
#     "category": "MULTIFAMILY",
#     "address": "6323 SAND POINT WAY NE"
#   },
#   {
#     "longitude": "-122.30442270",
#     "value": "36306",
#     "issue_date": "2016-05-12T00:00:00",
#     "application_permit_number": "6517579",
#     "action_type": "ADD/ALT",
#     "latitude": "47.66159817",
#     "category": "MULTIFAMILY",
#     "address": "4510 22ND AVE NE"
#   },
#   {
#     "longitude": "-122.34705940",
#     "value": "1583000",
#     "issue_date": "2016-05-10T00:00:00",
#     "application_permit_number": "6483012",
#     "action_type": "ADD/ALT",
#     "latitude": "47.66027266",
#     "category": "MULTIFAMILY",
#     "address": "4300 AURORA AVE N"
#   },
#   {
#     "longitude": "-122.26131660",
#     "value": "30000",
#     "issue_date": "2016-05-09T00:00:00",
#     "application_permit_number": "6532465",
#     "action_type": "ADD/ALT",
#     "latitude": "47.52126789",
#     "category": "MULTIFAMILY",
#     "address": "9500 RAINIER AVE S"
#   },
#   {
#     "longitude": "-122.32876744",
#     "value": "2057331",
#     "issue_date": "2016-05-09T00:00:00",
#     "application_permit_number": "6464363",
#     "action_type": "NEW",
#     "latitude": "47.68266564",
#     "category": "MULTIFAMILY",
#     "address": "7440 EAST GREEN LAKE DR N"
#   },
#   {
#     "longitude": "-122.35964685",
#     "value": "58000",
#     "issue_date": "2016-05-06T00:00:00",
#     "application_permit_number": "6533018",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62985781",
#     "category": "MULTIFAMILY",
#     "address": "200 W HIGHLAND DR"
#   },
#   {
#     "longitude": "-122.38930561",
#     "value": "478778",
#     "issue_date": "2016-05-06T00:00:00",
#     "application_permit_number": "6474348",
#     "action_type": "NEW",
#     "latitude": "47.67575339",
#     "category": "MULTIFAMILY",
#     "address": "2515 NW 65TH ST"
#   },
#   {
#     "longitude": "-122.32933488",
#     "value": "40000",
#     "issue_date": "2016-05-05T00:00:00",
#     "application_permit_number": "6533297",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61089077",
#     "category": "MULTIFAMILY",
#     "address": "900 UNIVERSITY ST"
#   },
#   {
#     "longitude": "-122.30780668",
#     "value": "450000",
#     "issue_date": "2016-05-05T00:00:00",
#     "application_permit_number": "6512309",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61820708",
#     "category": "MULTIFAMILY",
#     "address": "1819 E DENNY WAY"
#   },
#   {
#     "longitude": "-122.34835476",
#     "value": "50000",
#     "issue_date": "2016-05-03T00:00:00",
#     "application_permit_number": "6501162",
#     "action_type": "ADD/ALT",
#     "latitude": "47.69084082",
#     "category": "MULTIFAMILY",
#     "address": "730 N 85TH ST"
#   },
#   {
#     "longitude": "-122.33729971",
#     "value": "25000",
#     "issue_date": "2016-05-02T00:00:00",
#     "application_permit_number": "6532600",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61783173",
#     "category": "MULTIFAMILY",
#     "address": "2200 WESTLAKE AVE"
#   },
#   {
#     "longitude": "-122.32702723",
#     "value": "40000",
#     "issue_date": "2016-05-02T00:00:00",
#     "application_permit_number": "6530865",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61769861",
#     "category": "MULTIFAMILY",
#     "address": "1717 BELLEVUE AVE"
#   },
#   {
#     "longitude": "-122.33163123",
#     "value": "70000",
#     "issue_date": "2016-05-02T00:00:00",
#     "application_permit_number": "6503415",
#     "action_type": "ADD/ALT",
#     "latitude": "47.66050825",
#     "category": "MULTIFAMILY",
#     "address": "4405 CORLISS AVE N"
#   },
#   {
#     "longitude": "-122.32721261",
#     "value": "130000",
#     "issue_date": "2016-04-28T00:00:00",
#     "application_permit_number": "6525114",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61390837",
#     "category": "MULTIFAMILY",
#     "address": "303 E PIKE ST"
#   },
#   {
#     "longitude": "-122.39157610",
#     "value": "80000",
#     "issue_date": "2016-04-28T00:00:00",
#     "application_permit_number": "6520912",
#     "action_type": "ADD/ALT",
#     "latitude": "47.53860111",
#     "category": "MULTIFAMILY",
#     "address": "7135 FAUNTLEROY WAY SW"
#   },
#   {
#     "longitude": "-122.28813256",
#     "value": "1026361",
#     "issue_date": "2016-04-28T00:00:00",
#     "application_permit_number": "6485840",
#     "action_type": "NEW",
#     "latitude": "47.68187905",
#     "category": "MULTIFAMILY",
#     "address": "3628 NE 73RD PL"
#   },
#   {
#     "longitude": "-122.28690282",
#     "value": "600000",
#     "issue_date": "2016-04-26T00:00:00",
#     "application_permit_number": "6500328",
#     "action_type": "NEW",
#     "latitude": "47.56991545",
#     "category": "MULTIFAMILY",
#     "address": "3660 COURTLAND PL S"
#   },
#   {
#     "longitude": "-122.29807873",
#     "value": "786928",
#     "issue_date": "2016-04-26T00:00:00",
#     "application_permit_number": "6440671",
#     "action_type": "NEW",
#     "latitude": "47.62118988",
#     "category": "MULTIFAMILY",
#     "address": "2609 E THOMAS ST"
#   },
#   {
#     "longitude": "-122.32691332",
#     "value": "50000",
#     "issue_date": "2016-04-22T00:00:00",
#     "application_permit_number": "6511469",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63791829",
#     "category": "MULTIFAMILY",
#     "address": "2038 YALE AVE E"
#   },
#   {
#     "longitude": "-122.40137448",
#     "value": "373453",
#     "issue_date": "2016-04-22T00:00:00",
#     "application_permit_number": "6485885",
#     "action_type": "NEW",
#     "latitude": "47.66882483",
#     "category": "MULTIFAMILY",
#     "address": "3400 NW MARKET ST"
#   },
#   {
#     "longitude": "-122.32645363",
#     "value": "50000",
#     "issue_date": "2016-04-20T00:00:00",
#     "application_permit_number": "6502620",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62328587",
#     "category": "MULTIFAMILY",
#     "address": "502 BELLEVUE AVE E"
#   },
#   {
#     "longitude": "-122.38809669",
#     "value": "40000",
#     "issue_date": "2016-04-19T00:00:00",
#     "application_permit_number": "6530243",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67146019",
#     "category": "MULTIFAMILY",
#     "address": "2407 NW 59TH ST"
#   },
#   {
#     "longitude": "-122.34659425",
#     "value": "50000",
#     "issue_date": "2016-04-19T00:00:00",
#     "application_permit_number": "6485078",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63099904",
#     "category": "MULTIFAMILY",
#     "address": "1251 TAYLOR AVE N"
#   },
#   {
#     "longitude": "-122.35766771",
#     "value": "35103256",
#     "issue_date": "2016-04-19T00:00:00",
#     "application_permit_number": "6462925",
#     "action_type": "NEW",
#     "latitude": "47.62127489",
#     "category": "MULTIFAMILY",
#     "address": "427 9TH AVE N"
#   },
#   {
#     "longitude": "-122.31487587",
#     "value": "15000",
#     "issue_date": "2016-04-18T00:00:00",
#     "application_permit_number": "6529938",
#     "action_type": "ADD/ALT",
#     "latitude": "47.57885517",
#     "category": "MULTIFAMILY",
#     "address": "2721 14TH AVE S"
#   },
#   {
#     "longitude": "-122.37596197",
#     "value": "532041",
#     "issue_date": "2016-04-18T00:00:00",
#     "application_permit_number": "6488058",
#     "action_type": "NEW",
#     "latitude": "47.67965178",
#     "category": "MULTIFAMILY",
#     "address": "1468 NW 70TH ST"
#   },
#   {
#     "longitude": "-122.339443",
#     "value": "121548017",
#     "issue_date": "2016-04-18T00:00:00",
#     "application_permit_number": "6425811",
#     "action_type": "NEW",
#     "latitude": "47.61789385",
#     "category": "MULTIFAMILY",
#     "address": "2202 8TH AVE"
#   },
#   {
#     "longitude": "-122.28301568",
#     "value": "204518",
#     "issue_date": "2016-04-18T00:00:00",
#     "application_permit_number": "6344417",
#     "action_type": "NEW",
#     "latitude": "47.55311584",
#     "category": "MULTIFAMILY",
#     "address": "3907 S BRANDON ST"
#   },
#   {
#     "longitude": "-122.28294264",
#     "value": "201863",
#     "issue_date": "2016-04-18T00:00:00",
#     "application_permit_number": "6446314",
#     "action_type": "NEW",
#     "latitude": "47.55332365",
#     "category": "MULTIFAMILY",
#     "address": "3911 S BRANDON ST"
#   },
#   {
#     "longitude": "-122.28306922",
#     "value": "201863",
#     "issue_date": "2016-04-18T00:00:00",
#     "application_permit_number": "6446315",
#     "action_type": "NEW",
#     "latitude": "47.55332387",
#     "category": "MULTIFAMILY",
#     "address": "3905 S BRANDON ST"
#   },
#   {
#     "longitude": "-122.28293970",
#     "value": "207306",
#     "issue_date": "2016-04-18T00:00:00",
#     "application_permit_number": "6446316",
#     "action_type": "NEW",
#     "latitude": "47.55310895",
#     "category": "MULTIFAMILY",
#     "address": "3909 S BRANDON ST"
#   },
#   {
#     "longitude": "-122.33163123",
#     "value": "60000",
#     "issue_date": "2016-04-15T00:00:00",
#     "application_permit_number": "6529723",
#     "action_type": "ADD/ALT",
#     "latitude": "47.66050825",
#     "category": "MULTIFAMILY",
#     "address": "4405 CORLISS AVE N"
#   },
#   {
#     "longitude": "-122.34799082",
#     "value": "29000",
#     "issue_date": "2016-04-13T00:00:00",
#     "application_permit_number": "6472262",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63594864",
#     "category": "MULTIFAMILY",
#     "address": "1902 BIGELOW AVE N"
#   },
#   {
#     "longitude": "-122.30177668",
#     "value": "31000",
#     "issue_date": "2016-04-13T00:00:00",
#     "application_permit_number": "6529181",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61911912",
#     "category": "MULTIFAMILY",
#     "address": "2320 E DENNY WAY"
#   },
#   {
#     "longitude": "-122.38588712",
#     "value": "70000",
#     "issue_date": "2016-04-13T00:00:00",
#     "application_permit_number": "6513441",
#     "action_type": "ADD/ALT",
#     "latitude": "47.58969070",
#     "category": "MULTIFAMILY",
#     "address": "1520 CALIFORNIA AVE SW"
#   },
#   {
#     "longitude": "-122.32268625",
#     "value": "1614126",
#     "issue_date": "2016-04-13T00:00:00",
#     "application_permit_number": "6433185",
#     "action_type": "NEW",
#     "latitude": "47.62629031",
#     "category": "MULTIFAMILY",
#     "address": "741 HARVARD AVE E"
#   },
#   {
#     "longitude": "-122.35589245",
#     "value": "5000",
#     "issue_date": "2016-04-12T00:00:00",
#     "application_permit_number": "6519380",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62829769",
#     "category": "MULTIFAMILY",
#     "address": "12 WARD ST"
#   },
#   {
#     "longitude": "-122.31273275",
#     "value": "80000",
#     "issue_date": "2016-04-12T00:00:00",
#     "application_permit_number": "6502783",
#     "action_type": "ADD/ALT",
#     "latitude": "47.66761574",
#     "category": "MULTIFAMILY",
#     "address": "5240 UNIVERSITY WAY NE"
#   },
#   {
#     "longitude": "-122.29757703",
#     "value": "275000",
#     "issue_date": "2016-04-09T00:00:00",
#     "application_permit_number": "6502630",
#     "action_type": "ADD/ALT",
#     "latitude": "47.60741804",
#     "category": "MULTIFAMILY",
#     "address": "540 27TH AVE"
#   },
#   {
#     "longitude": "-122.35336543",
#     "value": "415000",
#     "issue_date": "2016-04-08T00:00:00",
#     "application_permit_number": "6507806",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61566330",
#     "category": "MULTIFAMILY",
#     "address": "2801 WESTERN AVE"
#   },
#   {
#     "longitude": "-122.31580511",
#     "value": "1389673",
#     "issue_date": "2016-04-05T00:00:00",
#     "application_permit_number": "6475222",
#     "action_type": "NEW",
#     "latitude": "47.61782102",
#     "category": "MULTIFAMILY",
#     "address": "1803 13TH AVE"
#   },
#   {
#     "longitude": "-122.28581293",
#     "value": "5837",
#     "issue_date": "2016-04-04T00:00:00",
#     "application_permit_number": "6504454",
#     "action_type": "ADD/ALT",
#     "latitude": "47.59968550",
#     "category": "MULTIFAMILY",
#     "address": "302 LAKESIDE AVE S"
#   },
#   {
#     "longitude": "-122.30016570",
#     "value": "65000",
#     "issue_date": "2016-04-04T00:00:00",
#     "application_permit_number": "6526560",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62048194",
#     "category": "MULTIFAMILY",
#     "address": "2421 E MADISON ST"
#   },
#   {
#     "longitude": "-122.30016570",
#     "value": "65000",
#     "issue_date": "2016-04-04T00:00:00",
#     "application_permit_number": "6526560",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62048194",
#     "category": "MULTIFAMILY",
#     "address": "2421 E MADISON ST"
#   },
#   {
#     "longitude": "-122.37841989",
#     "value": "627000",
#     "issue_date": "2016-04-01T00:00:00",
#     "application_permit_number": "6490582",
#     "action_type": "ADD/ALT",
#     "latitude": "47.64787497",
#     "category": "MULTIFAMILY",
#     "address": "3040 17TH AVE W"
#   },
#   {
#     "longitude": "-122.29230390",
#     "value": "860533",
#     "issue_date": "2016-04-01T00:00:00",
#     "application_permit_number": "6448778",
#     "action_type": "NEW",
#     "latitude": "47.56063803",
#     "category": "MULTIFAMILY",
#     "address": "4700 31ST AVE S"
#   },
#   {
#     "longitude": "-122.38780516",
#     "value": "2500",
#     "issue_date": "2016-03-30T00:00:00",
#     "application_permit_number": "6514191",
#     "action_type": "ADD/ALT",
#     "latitude": "47.65257550",
#     "category": "MULTIFAMILY",
#     "address": "3601 24TH AVE W"
#   },
#   {
#     "longitude": "-122.32310494",
#     "value": "108000",
#     "issue_date": "2016-03-30T00:00:00",
#     "application_permit_number": "6496769",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61619606",
#     "category": "MULTIFAMILY",
#     "address": "1630 BOYLSTON AVE"
#   },
#   {
#     "longitude": "-122.31180797",
#     "value": "50000",
#     "issue_date": "2016-03-29T00:00:00",
#     "application_permit_number": "6503528",
#     "action_type": "ADD/ALT",
#     "latitude": "47.68636183",
#     "category": "MULTIFAMILY",
#     "address": "7750 15TH AVE NE"
#   },
#   {
#     "longitude": "-122.37452636",
#     "value": "415511",
#     "issue_date": "2016-03-29T00:00:00",
#     "application_permit_number": "6493116",
#     "action_type": "NEW",
#     "latitude": "47.65006193",
#     "category": "MULTIFAMILY",
#     "address": "3250 14TH AVE W"
#   },
#   {
#     "longitude": "-122.37452454",
#     "value": "620687",
#     "issue_date": "2016-03-29T00:00:00",
#     "application_permit_number": "6453368",
#     "action_type": "NEW",
#     "latitude": "47.64991394",
#     "category": "MULTIFAMILY",
#     "address": "3248 14TH AVE W"
#   },
#   {
#     "longitude": "-122.37452636",
#     "value": "341583",
#     "issue_date": "2016-03-29T00:00:00",
#     "application_permit_number": "6493117",
#     "action_type": "NEW",
#     "latitude": "47.65006193",
#     "category": "MULTIFAMILY",
#     "address": "3252 14TH AVE W"
#   },
#   {
#     "longitude": "-122.37452454",
#     "value": "502250",
#     "issue_date": "2016-03-29T00:00:00",
#     "application_permit_number": "6493118",
#     "action_type": "NEW",
#     "latitude": "47.64991394",
#     "category": "MULTIFAMILY",
#     "address": "3246 14TH AVE W"
#   },
#   {
#     "longitude": "-122.33473615",
#     "value": "18118470",
#     "issue_date": "2016-03-25T00:00:00",
#     "application_permit_number": "6463254",
#     "action_type": "NEW",
#     "latitude": "47.62235544",
#     "category": "MULTIFAMILY",
#     "address": "1401 E MADISON ST"
#   },
#   {
#     "longitude": "-122.38992418",
#     "value": "55000",
#     "issue_date": "2016-03-24T00:00:00",
#     "application_permit_number": "6492696",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67105809",
#     "category": "MULTIFAMILY",
#     "address": "2450 NW 58TH ST"
#   },
#   {
#     "longitude": "-122.35177092",
#     "value": "395941",
#     "issue_date": "2016-03-24T00:00:00",
#     "application_permit_number": "6471049",
#     "action_type": "NEW",
#     "latitude": "47.66050419",
#     "category": "MULTIFAMILY",
#     "address": "4406 DAYTON AVE N"
#   },
#   {
#     "longitude": "-122.35163221",
#     "value": "262121",
#     "issue_date": "2016-03-24T00:00:00",
#     "application_permit_number": "6495805",
#     "action_type": "NEW",
#     "latitude": "47.66050387",
#     "category": "MULTIFAMILY",
#     "address": "4404 DAYTON AVE N"
#   },
#   {
#     "longitude": "-122.34905307",
#     "value": "45000",
#     "issue_date": "2016-03-24T00:00:00",
#     "application_permit_number": "6481423",
#     "action_type": "ADD/ALT",
#     "latitude": "47.69081453",
#     "category": "MULTIFAMILY",
#     "address": "718 N 85TH ST"
#   },
#   {
#     "longitude": "-122.34844240",
#     "value": "16500",
#     "issue_date": "2016-03-23T00:00:00",
#     "application_permit_number": "6525530",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62684454",
#     "category": "MULTIFAMILY",
#     "address": "804 4TH AVE N"
#   },
#   {
#     "longitude": "-122.33361582",
#     "value": "60000",
#     "issue_date": "2016-03-23T00:00:00",
#     "application_permit_number": "6524520",
#     "action_type": "ADD/ALT",
#     "latitude": "47.65161760",
#     "category": "MULTIFAMILY",
#     "address": "3638 MERIDIAN AVE N"
#   },
#   {
#     "longitude": "-122.35830218",
#     "value": "127400",
#     "issue_date": "2016-03-23T00:00:00",
#     "application_permit_number": "6525423",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62374601",
#     "category": "MULTIFAMILY",
#     "address": "515 1ST AVE W"
#   },
#   {
#     "longitude": "-122.37669591",
#     "value": "1754064",
#     "issue_date": "2016-03-23T00:00:00",
#     "application_permit_number": "6407331",
#     "action_type": "NEW",
#     "latitude": "47.67330639",
#     "category": "MULTIFAMILY",
#     "address": "1506 NW 61ST ST"
#   },
#   {
#     "longitude": "-122.38906485",
#     "value": "16000",
#     "issue_date": "2016-03-21T00:00:00",
#     "application_permit_number": "6525077",
#     "action_type": "ADD/ALT",
#     "latitude": "47.65539962",
#     "category": "MULTIFAMILY",
#     "address": "3845 25TH AVE W"
#   },
#   {
#     "longitude": "-122.38906485",
#     "value": "16000",
#     "issue_date": "2016-03-21T00:00:00",
#     "application_permit_number": "6525077",
#     "action_type": "ADD/ALT",
#     "latitude": "47.65539962",
#     "category": "MULTIFAMILY",
#     "address": "3845 25TH AVE W"
#   },
#   {
#     "longitude": "-122.38906485",
#     "value": "16000",
#     "issue_date": "2016-03-21T00:00:00",
#     "application_permit_number": "6525077",
#     "action_type": "ADD/ALT",
#     "latitude": "47.65539962",
#     "category": "MULTIFAMILY",
#     "address": "3845 25TH AVE W"
#   },
#   {
#     "longitude": "-122.38137209",
#     "value": "40000",
#     "issue_date": "2016-03-21T00:00:00",
#     "application_permit_number": "6524982",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67035760",
#     "category": "MULTIFAMILY",
#     "address": "1756 NW 57TH ST"
#   },
#   {
#     "longitude": "-122.32443756",
#     "value": "560552",
#     "issue_date": "2016-03-21T00:00:00",
#     "application_permit_number": "6497047",
#     "action_type": "NEW",
#     "latitude": "47.64137454",
#     "category": "MULTIFAMILY",
#     "address": "307 W OLYMPIC PL"
#   },
#   {
#     "longitude": "-122.35156635",
#     "value": "524190",
#     "issue_date": "2016-03-21T00:00:00",
#     "application_permit_number": "6452364",
#     "action_type": "NEW",
#     "latitude": "47.65222822",
#     "category": "MULTIFAMILY",
#     "address": "3613 EVANSTON AVE N"
#   },
#   {
#     "longitude": "-122.35158097",
#     "value": "403248",
#     "issue_date": "2016-03-21T00:00:00",
#     "application_permit_number": "6493101",
#     "action_type": "NEW",
#     "latitude": "47.65223404",
#     "category": "MULTIFAMILY",
#     "address": "3615 EVANSTON AVE N"
#   },
#   {
#     "longitude": "-122.34646234",
#     "value": "135000",
#     "issue_date": "2016-03-18T00:00:00",
#     "application_permit_number": "6506715",
#     "action_type": "ADD/ALT",
#     "latitude": "47.64364830",
#     "category": "MULTIFAMILY",
#     "address": "2565 DEXTER AVE N"
#   },
#   {
#     "longitude": "-122.38680930",
#     "value": "200000",
#     "issue_date": "2016-03-14T00:00:00",
#     "application_permit_number": "6523872",
#     "action_type": "ADD/ALT",
#     "latitude": "47.58484556",
#     "category": "MULTIFAMILY",
#     "address": "2115 CALIFORNIA AVE SW"
#   },
#   {
#     "longitude": "-122.36130756",
#     "value": "1866723",
#     "issue_date": "2016-03-14T00:00:00",
#     "application_permit_number": "6501765",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62611651",
#     "category": "MULTIFAMILY",
#     "address": "320 W ROY ST"
#   },
#   {
#     "longitude": "-122.31251987",
#     "value": "62472",
#     "issue_date": "2016-03-11T00:00:00",
#     "application_permit_number": "6523377",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61134858",
#     "category": "MULTIFAMILY",
#     "address": "1501 E SPRING ST"
#   },
#   {
#     "longitude": "-122.37635946",
#     "value": "20000",
#     "issue_date": "2016-03-10T00:00:00",
#     "application_permit_number": "6523342",
#     "action_type": "ADD/ALT",
#     "latitude": "47.52212560",
#     "category": "MULTIFAMILY",
#     "address": "9020 35TH AVE SW"
#   },
#   {
#     "longitude": "-122.31584809",
#     "value": "76440",
#     "issue_date": "2016-03-09T00:00:00",
#     "application_permit_number": "6476029",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61022380",
#     "category": "MULTIFAMILY",
#     "address": "1219 E MARION ST"
#   },
#   {
#     "longitude": "-122.30065926",
#     "value": "1100829",
#     "issue_date": "2016-03-09T00:00:00",
#     "application_permit_number": "6439091",
#     "action_type": "NEW",
#     "latitude": "47.58277721",
#     "category": "MULTIFAMILY",
#     "address": "2467 S COLLEGE ST"
#   },
#   {
#     "longitude": "-122.38542950",
#     "value": "1",
#     "issue_date": "2016-03-08T00:00:00",
#     "application_permit_number": "6522932",
#     "action_type": "ADD/ALT",
#     "latitude": "47.64235767",
#     "category": "MULTIFAMILY",
#     "address": "2551 THORNDYKE AVE W"
#   },
#   {
#     "longitude": "-122.37351613",
#     "value": "711345",
#     "issue_date": "2016-03-08T00:00:00",
#     "application_permit_number": "6469290",
#     "action_type": "NEW",
#     "latitude": "47.69538728",
#     "category": "MULTIFAMILY",
#     "address": "9036 14TH AVE NW"
#   },
#   {
#     "longitude": "-122.34719784",
#     "value": "50000",
#     "issue_date": "2016-03-07T00:00:00",
#     "application_permit_number": "6492896",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62869012",
#     "category": "MULTIFAMILY",
#     "address": "1020 5TH AVE N"
#   },
#   {
#     "longitude": "-122.32440405",
#     "value": "338721",
#     "issue_date": "2016-03-07T00:00:00",
#     "application_permit_number": "6462342",
#     "action_type": "NEW",
#     "latitude": "47.63910860",
#     "category": "MULTIFAMILY",
#     "address": "2228 FRANKLIN AVE E"
#   },
#   {
#     "longitude": "-122.32423203",
#     "value": "357930",
#     "issue_date": "2016-03-07T00:00:00",
#     "application_permit_number": "6495887",
#     "action_type": "NEW",
#     "latitude": "47.63911237",
#     "category": "MULTIFAMILY",
#     "address": "2226 FRANKLIN AVE E"
#   },
#   {
#     "longitude": "-122.27653038",
#     "value": "28109",
#     "issue_date": "2016-03-04T00:00:00",
#     "application_permit_number": "6481375",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63429424",
#     "category": "MULTIFAMILY",
#     "address": "1630 43RD AVE E"
#   },
#   {
#     "longitude": "-122.35780864",
#     "value": "10836537",
#     "issue_date": "2016-03-04T00:00:00",
#     "application_permit_number": "6459262",
#     "action_type": "NEW",
#     "latitude": "47.62195673",
#     "category": "MULTIFAMILY",
#     "address": "19 W HARRISON ST"
#   },
#   {
#     "longitude": "-122.36370956",
#     "value": "599646",
#     "issue_date": "2016-03-02T00:00:00",
#     "application_permit_number": "6476329",
#     "action_type": "NEW",
#     "latitude": "47.56623365",
#     "category": "MULTIFAMILY",
#     "address": "4107 DELRIDGE WAY SW"
#   },
#   {
#     "longitude": "-122.30552643",
#     "value": "15000",
#     "issue_date": "2016-03-01T00:00:00",
#     "application_permit_number": "6518931",
#     "action_type": "ADD/ALT",
#     "latitude": "47.60109766",
#     "category": "MULTIFAMILY",
#     "address": "2001 E YESLER WAY"
#   },
#   {
#     "longitude": "-122.36431386",
#     "value": "70000",
#     "issue_date": "2016-03-01T00:00:00",
#     "application_permit_number": "6516341",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62523212",
#     "category": "MULTIFAMILY",
#     "address": "526 W MERCER PL"
#   },
#   {
#     "longitude": "-122.38034895",
#     "value": "3580492",
#     "issue_date": "2016-03-01T00:00:00",
#     "application_permit_number": "6473388",
#     "action_type": "NEW",
#     "latitude": "47.66992910",
#     "category": "MULTIFAMILY",
#     "address": "1731 NW 57TH ST"
#   },
#   {
#     "longitude": "-122.30579260",
#     "value": "625000",
#     "issue_date": "2016-02-26T00:00:00",
#     "application_permit_number": "6487511",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61896419",
#     "category": "MULTIFAMILY",
#     "address": "114 20TH AVE E"
#   },
#   {
#     "longitude": "-122.30573103",
#     "value": "575000",
#     "issue_date": "2016-02-26T00:00:00",
#     "application_permit_number": "6500587",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61866122",
#     "category": "MULTIFAMILY",
#     "address": "100 20TH AVE E"
#   },
#   {
#     "longitude": "-122.32530963",
#     "value": "1725000",
#     "issue_date": "2016-02-26T00:00:00",
#     "application_permit_number": "6451677",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61706480",
#     "category": "MULTIFAMILY",
#     "address": "1722 SUMMIT AVE"
#   },
#   {
#     "longitude": "-122.37641675",
#     "value": "215000",
#     "issue_date": "2016-02-26T00:00:00",
#     "application_permit_number": "6382806",
#     "action_type": "NEW",
#     "latitude": "47.68004583",
#     "category": "MULTIFAMILY",
#     "address": "7016 15TH AVE NW"
#   },
#   {
#     "longitude": "-122.31459178",
#     "value": "30000",
#     "issue_date": "2016-02-25T00:00:00",
#     "application_permit_number": "6484808",
#     "action_type": "ADD/ALT",
#     "latitude": "47.66727625",
#     "category": "MULTIFAMILY",
#     "address": "5227 BROOKLYN AVE NE"
#   },
#   {
#     "longitude": "-122.31985773",
#     "value": "1346469",
#     "issue_date": "2016-02-24T00:00:00",
#     "application_permit_number": "6455438",
#     "action_type": "NEW",
#     "latitude": "47.67717571",
#     "category": "MULTIFAMILY",
#     "address": "6616 8TH AVE NE"
#   },
#   {
#     "longitude": "-122.32267906",
#     "value": "10000",
#     "issue_date": "2016-02-23T00:00:00",
#     "application_permit_number": "6520428",
#     "action_type": "ADD/ALT",
#     "latitude": "47.71021477",
#     "category": "MULTIFAMILY",
#     "address": "514 NE 112TH ST"
#   },
#   {
#     "longitude": "-122.31669246",
#     "value": "70178",
#     "issue_date": "2016-02-22T00:00:00",
#     "application_permit_number": "6519912",
#     "action_type": "ADD/ALT",
#     "latitude": "47.71969414",
#     "category": "MULTIFAMILY",
#     "address": "1030 NE 125TH ST"
#   },
#   {
#     "longitude": "-122.33189923",
#     "value": "40000",
#     "issue_date": "2016-02-20T00:00:00",
#     "application_permit_number": "6500464",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62010847",
#     "category": "MULTIFAMILY",
#     "address": "215 PONTIUS AVE N"
#   },
#   {
#     "longitude": "-122.31756146",
#     "value": "186000",
#     "issue_date": "2016-02-19T00:00:00",
#     "application_permit_number": "6519843",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61388874",
#     "category": "MULTIFAMILY",
#     "address": "1111 E PIKE ST"
#   },
#   {
#     "longitude": "-122.39410886",
#     "value": "20000",
#     "issue_date": "2016-02-19T00:00:00",
#     "application_permit_number": "6497647",
#     "action_type": "ADD/ALT",
#     "latitude": "47.53979082",
#     "category": "MULTIFAMILY",
#     "address": "7019 47TH AVE SW"
#   },
#   {
#     "longitude": "-122.34357373",
#     "value": "206606",
#     "issue_date": "2016-02-19T00:00:00",
#     "application_permit_number": "6471163",
#     "action_type": "NEW",
#     "latitude": "47.63873370",
#     "category": "MULTIFAMILY",
#     "address": "2138 DEXTER AVE N"
#   },
#   {
#     "longitude": "-122.34343983",
#     "value": "295690",
#     "issue_date": "2016-02-19T00:00:00",
#     "application_permit_number": "6489530",
#     "action_type": "NEW",
#     "latitude": "47.63875014",
#     "category": "MULTIFAMILY",
#     "address": "2136 DEXTER AVE N"
#   },
#   {
#     "longitude": "-122.30860585",
#     "value": "80000",
#     "issue_date": "2016-02-18T00:00:00",
#     "application_permit_number": "6474853",
#     "action_type": "ADD/ALT",
#     "latitude": "47.619522",
#     "category": "MULTIFAMILY",
#     "address": "1803 E JOHN ST"
#   },
#   {
#     "longitude": "-122.33948481",
#     "value": "25000",
#     "issue_date": "2016-02-18T00:00:00",
#     "application_permit_number": "6486930",
#     "action_type": "ADD/ALT",
#     "latitude": "47.70121116",
#     "category": "MULTIFAMILY",
#     "address": "9750 ASHWORTH AVE N"
#   },
#   {
#     "longitude": "-122.35699852",
#     "value": "606497",
#     "issue_date": "2016-02-18T00:00:00",
#     "application_permit_number": "6468397",
#     "action_type": "NEW",
#     "latitude": "47.52184247",
#     "category": "MULTIFAMILY",
#     "address": "9035 17TH AVE SW"
#   },
#   {
#     "longitude": "-122.38541264",
#     "value": "6000",
#     "issue_date": "2016-02-17T00:00:00",
#     "application_permit_number": "6519419",
#     "action_type": "ADD/ALT",
#     "latitude": "47.58340509",
#     "category": "MULTIFAMILY",
#     "address": "2217 42ND AVE SW"
#   },
#   {
#     "longitude": "-122.31397516",
#     "value": "75000",
#     "issue_date": "2016-02-17T00:00:00",
#     "application_permit_number": "6518297",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62212472",
#     "category": "MULTIFAMILY",
#     "address": "1414 E HARRISON ST"
#   },
#   {
#     "longitude": "-122.37540766",
#     "value": "497050",
#     "issue_date": "2016-02-17T00:00:00",
#     "application_permit_number": "6477239",
#     "action_type": "NEW",
#     "latitude": "47.54396150",
#     "category": "MULTIFAMILY",
#     "address": "6523 34TH AVE SW"
#   },
#   {
#     "longitude": "-122.35954943",
#     "value": "1000",
#     "issue_date": "2016-02-11T00:00:00",
#     "application_permit_number": "6516137",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63203957",
#     "category": "MULTIFAMILY",
#     "address": "1417 2ND AVE W"
#   },
#   {
#     "longitude": "-122.36986001",
#     "value": "477410",
#     "issue_date": "2016-02-10T00:00:00",
#     "application_permit_number": "6478176",
#     "action_type": "NEW",
#     "latitude": "47.63832042",
#     "category": "MULTIFAMILY",
#     "address": "2116 10TH AVE W"
#   },
#   {
#     "longitude": "-122.36981599",
#     "value": "234069",
#     "issue_date": "2016-02-10T00:00:00",
#     "application_permit_number": "6438717",
#     "action_type": "NEW",
#     "latitude": "47.63837855",
#     "category": "MULTIFAMILY",
#     "address": "2120 10TH AVE W"
#   },
#   {
#     "value": "100000",
#     "issue_date": "2016-02-09T00:00:00",
#     "application_permit_number": "6517679",
#     "action_type": "ADD/ALT",
#     "address": "417409 E PINE ST",
#     "category": "MULTIFAMILY"
#   },
#   {
#     "longitude": "-122.27625869",
#     "value": "60000",
#     "issue_date": "2016-02-08T00:00:00",
#     "application_permit_number": "6517720",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63383468",
#     "category": "MULTIFAMILY",
#     "address": "1620 43RD AVE E"
#   },
#   {
#     "longitude": "-122.30335134",
#     "value": "85000",
#     "issue_date": "2016-02-08T00:00:00",
#     "application_permit_number": "6516971",
#     "action_type": "ADD/ALT",
#     "latitude": "47.60188006",
#     "category": "MULTIFAMILY",
#     "address": "106 22ND AVE"
#   },
#   {
#     "longitude": "-122.30801538",
#     "value": "15000",
#     "issue_date": "2016-02-08T00:00:00",
#     "application_permit_number": "6517181",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62027633",
#     "category": "MULTIFAMILY",
#     "address": "1815 E THOMAS ST"
#   },
#   {
#     "longitude": "-122.34978093",
#     "value": "4000",
#     "issue_date": "2016-02-04T00:00:00",
#     "application_permit_number": "6517546",
#     "action_type": "ADD/ALT",
#     "latitude": "47.65858625",
#     "category": "MULTIFAMILY",
#     "address": "4228 FREMONT AVE N"
#   },
#   {
#     "longitude": "-122.32933488",
#     "value": "45000",
#     "issue_date": "2016-02-03T00:00:00",
#     "application_permit_number": "6517233",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61089077",
#     "category": "MULTIFAMILY",
#     "address": "900 UNIVERSITY ST"
#   },
#   {
#     "longitude": "-122.38741504",
#     "value": "450000",
#     "issue_date": "2016-02-03T00:00:00",
#     "application_permit_number": "6499903",
#     "action_type": "ADD/ALT",
#     "latitude": "47.55667869",
#     "category": "MULTIFAMILY",
#     "address": "5025 CALIFORNIA AVE SW"
#   },
#   {
#     "longitude": "-122.31771616",
#     "value": "4502144",
#     "issue_date": "2016-01-28T00:00:00",
#     "application_permit_number": "6410037",
#     "action_type": "NEW",
#     "latitude": "47.67295718",
#     "category": "MULTIFAMILY",
#     "address": "6105 ROOSEVELT WAY NE"
#   },
#   {
#     "longitude": "-122.26402241",
#     "value": "2000",
#     "issue_date": "2016-01-27T00:00:00",
#     "application_permit_number": "6515957",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67966066",
#     "category": "MULTIFAMILY",
#     "address": "7021 SAND POINT WAY NE"
#   },
#   {
#     "longitude": "-122.26459329",
#     "value": "2000",
#     "issue_date": "2016-01-27T00:00:00",
#     "application_permit_number": "6515964",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67966793",
#     "category": "MULTIFAMILY",
#     "address": "5818 NE 70TH ST"
#   },
#   {
#     "longitude": "-122.37511445",
#     "value": "11066",
#     "issue_date": "2016-01-27T00:00:00",
#     "application_permit_number": "6498818",
#     "action_type": "ADD/ALT",
#     "latitude": "47.58143778",
#     "category": "MULTIFAMILY",
#     "address": "2349 FAUNTLEROY AVE SW"
#   },
#   {
#     "longitude": "-122.32109847",
#     "value": "10000",
#     "issue_date": "2016-01-27T00:00:00",
#     "application_permit_number": "6505737",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63703584",
#     "category": "MULTIFAMILY",
#     "address": "909 E NEWTON ST"
#   },
#   {
#     "longitude": "-122.37116390",
#     "value": "418373",
#     "issue_date": "2016-01-27T00:00:00",
#     "application_permit_number": "6480632",
#     "action_type": "NEW",
#     "latitude": "47.63760526",
#     "category": "MULTIFAMILY",
#     "address": "1015 W CROCKETT ST"
#   },
#   {
#     "longitude": "-122.34704340",
#     "value": "556995",
#     "issue_date": "2016-01-27T00:00:00",
#     "application_permit_number": "6479416",
#     "action_type": "NEW",
#     "latitude": "47.62928555",
#     "category": "MULTIFAMILY",
#     "address": "510 PROSPECT ST"
#   },
#   {
#     "longitude": "-122.33927313",
#     "value": "20000",
#     "issue_date": "2016-01-26T00:00:00",
#     "application_permit_number": "6515764",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61296669",
#     "category": "MULTIFAMILY",
#     "address": "1920 4TH AVE"
#   },
#   {
#     "longitude": "-122.31053404",
#     "value": "743654",
#     "issue_date": "2016-01-26T00:00:00",
#     "application_permit_number": "6463139",
#     "action_type": "NEW",
#     "latitude": "47.61898194",
#     "category": "MULTIFAMILY",
#     "address": "113 17TH AVE E"
#   },
#   {
#     "longitude": "-122.33623046",
#     "value": "47867204",
#     "issue_date": "2016-01-26T00:00:00",
#     "application_permit_number": "6436709",
#     "action_type": "NEW",
#     "latitude": "47.62369467",
#     "category": "MULTIFAMILY",
#     "address": "1319 DEXTER AVE N"
#   },
#   {
#     "longitude": "-122.35512992",
#     "value": "800000",
#     "issue_date": "2016-01-25T00:00:00",
#     "application_permit_number": "6443119",
#     "action_type": "ADD/ALT",
#     "latitude": "47.71391139",
#     "category": "MULTIFAMILY",
#     "address": "11556 GREENWOOD AVE N"
#   },
#   {
#     "longitude": "-122.29835381",
#     "value": "796418",
#     "issue_date": "2016-01-25T00:00:00",
#     "application_permit_number": "6445382",
#     "action_type": "NEW",
#     "latitude": "47.62120141",
#     "category": "MULTIFAMILY",
#     "address": "230 26TH AVE E"
#   },
#   {
#     "longitude": "-122.35507365",
#     "value": "90000",
#     "issue_date": "2016-01-25T00:00:00",
#     "application_permit_number": "6486169",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62670225",
#     "category": "MULTIFAMILY",
#     "address": "800 1ST AVE N"
#   },
#   {
#     "longitude": "-122.35507365",
#     "value": "30000",
#     "issue_date": "2016-01-25T00:00:00",
#     "application_permit_number": "6487486",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62670225",
#     "category": "MULTIFAMILY",
#     "address": "800 1ST AVE N"
#   },
#   {
#     "longitude": "-122.35697457",
#     "value": "30000",
#     "issue_date": "2016-01-20T00:00:00",
#     "application_permit_number": "6514681",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63028873",
#     "category": "MULTIFAMILY",
#     "address": "1221 QUEEN ANNE AVE N"
#   },
#   {
#     "longitude": "-122.26952102",
#     "value": "30000",
#     "issue_date": "2016-01-20T00:00:00",
#     "application_permit_number": "6514659",
#     "action_type": "ADD/ALT",
#     "latitude": "47.69257812",
#     "category": "MULTIFAMILY",
#     "address": "8716 SAND POINT WAY NE"
#   },
#   {
#     "longitude": "-122.34381074",
#     "value": "1019455",
#     "issue_date": "2016-01-20T00:00:00",
#     "application_permit_number": "6456300",
#     "action_type": "NEW",
#     "latitude": "47.73249890",
#     "category": "MULTIFAMILY",
#     "address": "14300 MIDVALE AVE N"
#   },
#   {
#     "longitude": "-122.34402959",
#     "value": "15000",
#     "issue_date": "2016-01-19T00:00:00",
#     "application_permit_number": "6514444",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61156449",
#     "category": "MULTIFAMILY",
#     "address": "2033 1ST AVE"
#   },
#   {
#     "longitude": "-122.31050531",
#     "value": "744262",
#     "issue_date": "2016-01-19T00:00:00",
#     "application_permit_number": "6433988",
#     "action_type": "NEW",
#     "latitude": "47.61906370",
#     "category": "MULTIFAMILY",
#     "address": "117 17TH AVE E"
#   },
#   {
#     "longitude": "-122.31351213",
#     "value": "19500",
#     "issue_date": "2016-01-13T00:00:00",
#     "application_permit_number": "6513656",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61621126",
#     "category": "MULTIFAMILY",
#     "address": "1415 E OLIVE ST"
#   },
#   {
#     "longitude": "-122.32801269",
#     "value": "15000",
#     "issue_date": "2016-01-13T00:00:00",
#     "application_permit_number": "6513654",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61266541",
#     "category": "MULTIFAMILY",
#     "address": "1400 BOREN AVE"
#   },
#   {
#     "longitude": "-122.31461717",
#     "value": "12000",
#     "issue_date": "2016-01-13T00:00:00",
#     "application_permit_number": "6512304",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62042470",
#     "category": "MULTIFAMILY",
#     "address": "215 14TH AVE E"
#   },
#   {
#     "longitude": "-122.29647666",
#     "value": "5149402",
#     "issue_date": "2016-01-13T00:00:00",
#     "application_permit_number": "6440247",
#     "action_type": "NEW",
#     "latitude": "47.61256623",
#     "category": "MULTIFAMILY",
#     "address": "1141 M L KING JR WAY"
#   },
#   {
#     "longitude": "-122.32267906",
#     "value": "50000",
#     "issue_date": "2016-01-12T00:00:00",
#     "application_permit_number": "6484122",
#     "action_type": "ADD/ALT",
#     "latitude": "47.71021477",
#     "category": "MULTIFAMILY",
#     "address": "514 NE 112TH ST"
#   },
#   {
#     "longitude": "-122.31594780",
#     "value": "50000",
#     "issue_date": "2016-01-11T00:00:00",
#     "application_permit_number": "6513114",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61338199",
#     "category": "MULTIFAMILY",
#     "address": "1222 E MADISON ST"
#   },
#   {
#     "longitude": "-122.32762760",
#     "value": "1141169",
#     "issue_date": "2016-01-11T00:00:00",
#     "application_permit_number": "6459558",
#     "action_type": "NEW",
#     "latitude": "47.65443675",
#     "category": "MULTIFAMILY",
#     "address": "3920 1ST AVE NE"
#   },
#   {
#     "longitude": "-122.32764251",
#     "value": "368749",
#     "issue_date": "2016-01-11T00:00:00",
#     "application_permit_number": "6469770",
#     "action_type": "NEW",
#     "latitude": "47.65434156",
#     "category": "MULTIFAMILY",
#     "address": "3918 1ST AVE NE"
#   },
#   {
#     "longitude": "-122.28099805",
#     "value": "1391102",
#     "issue_date": "2016-01-11T00:00:00",
#     "application_permit_number": "6396997",
#     "action_type": "NEW",
#     "latitude": "47.55568593",
#     "category": "MULTIFAMILY",
#     "address": "5153 42ND AVE S"
#   },
#   {
#     "longitude": "-122.28563066",
#     "value": "50000",
#     "issue_date": "2016-01-08T00:00:00",
#     "application_permit_number": "6508658",
#     "action_type": "ADD/ALT",
#     "latitude": "47.60001382",
#     "category": "MULTIFAMILY",
#     "address": "300 LAKESIDE AVE S"
#   },
#   {
#     "longitude": "-122.38996002",
#     "value": "53411",
#     "issue_date": "2016-01-08T00:00:00",
#     "application_permit_number": "6489943",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67120664",
#     "category": "MULTIFAMILY",
#     "address": "1238 E CROCKETT ST"
#   },
#   {
#     "longitude": "-122.37422090",
#     "value": "68000",
#     "issue_date": "2016-01-07T00:00:00",
#     "application_permit_number": "6512665",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63939367",
#     "category": "MULTIFAMILY",
#     "address": "2223 13TH AVE W"
#   },
#   {
#     "longitude": "-122.38578074",
#     "value": "34486",
#     "issue_date": "2016-01-07T00:00:00",
#     "application_permit_number": "6490637",
#     "action_type": "ADD/ALT",
#     "latitude": "47.64189708",
#     "category": "MULTIFAMILY",
#     "address": "2515 THORNDYKE AVE W"
#   },
#   {
#     "longitude": "-122.28123490",
#     "value": "807103",
#     "issue_date": "2016-01-07T00:00:00",
#     "application_permit_number": "6352649",
#     "action_type": "NEW",
#     "latitude": "47.55555438",
#     "category": "MULTIFAMILY",
#     "address": "5177 42ND AVE S"
#   },
#   {
#     "longitude": "-122.28100819",
#     "value": "401792",
#     "issue_date": "2016-01-07T00:00:00",
#     "application_permit_number": "6397639",
#     "action_type": "NEW",
#     "latitude": "47.555578",
#     "category": "MULTIFAMILY",
#     "address": "5159 42ND AVE S"
#   },
#   {
#     "longitude": "-122.32739151",
#     "value": "75000",
#     "issue_date": "2016-01-06T00:00:00",
#     "application_permit_number": "6484589",
#     "action_type": "ADD/ALT",
#     "latitude": "47.60072061",
#     "category": "MULTIFAMILY",
#     "address": "200 5TH AVE S"
#   },
#   {
#     "longitude": "-122.39792411",
#     "value": "15000",
#     "issue_date": "2016-01-05T00:00:00",
#     "application_permit_number": "6500837",
#     "action_type": "ADD/ALT",
#     "latitude": "47.64611839",
#     "category": "MULTIFAMILY",
#     "address": "2858 32ND AVE W"
#   },
#   {
#     "longitude": "-122.32369683",
#     "value": "20000",
#     "issue_date": "2016-01-05T00:00:00",
#     "application_permit_number": "6512142",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63956282",
#     "category": "MULTIFAMILY",
#     "address": "625 E LYNN ST"
#   },
#   {
#     "longitude": "-122.32337803",
#     "value": "346933",
#     "issue_date": "2016-01-04T00:00:00",
#     "application_permit_number": "6437187",
#     "action_type": "NEW",
#     "latitude": "47.55139215",
#     "category": "MULTIFAMILY",
#     "address": "721 S HOMER ST"
#   },
#   {
#     "longitude": "-122.38661682",
#     "value": "35000",
#     "issue_date": "2015-12-30T00:00:00",
#     "application_permit_number": "6456746",
#     "action_type": "ADD/ALT",
#     "latitude": "47.58862599",
#     "category": "MULTIFAMILY",
#     "address": "1621 CALIFORNIA AVE SW"
#   },
#   {
#     "longitude": "-122.37332311",
#     "value": "57480",
#     "issue_date": "2015-12-28T00:00:00",
#     "application_permit_number": "6500318",
#     "action_type": "ADD/ALT",
#     "latitude": "47.64005760",
#     "category": "MULTIFAMILY",
#     "address": "2244 13TH AVE W"
#   },
#   {
#     "longitude": "-122.32236808",
#     "value": "80000",
#     "issue_date": "2015-12-23T00:00:00",
#     "application_permit_number": "6501825",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62461457",
#     "category": "MULTIFAMILY",
#     "address": "611 HARVARD AVE E"
#   },
#   {
#     "longitude": "-122.30664238",
#     "value": "437958",
#     "issue_date": "2015-12-22T00:00:00",
#     "application_permit_number": "6457058",
#     "action_type": "NEW",
#     "latitude": "47.61838071",
#     "category": "MULTIFAMILY",
#     "address": "1917 E DENNY WAY"
#   },
#   {
#     "longitude": "-122.32503218",
#     "value": "34235",
#     "issue_date": "2015-12-21T00:00:00",
#     "application_permit_number": "6492465",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63516613",
#     "category": "MULTIFAMILY",
#     "address": "1800 EASTLAKE AVE E"
#   },
#   {
#     "longitude": "-122.33116523",
#     "value": "219473",
#     "issue_date": "2015-12-18T00:00:00",
#     "application_permit_number": "6469888",
#     "action_type": "NEW",
#     "latitude": "47.66061840",
#     "category": "MULTIFAMILY",
#     "address": "4410 CORLISS AVE N"
#   },
#   {
#     "longitude": "-122.33106106",
#     "value": "252903",
#     "issue_date": "2015-12-18T00:00:00",
#     "application_permit_number": "6480718",
#     "action_type": "NEW",
#     "latitude": "47.66062138",
#     "category": "MULTIFAMILY",
#     "address": "4408 CORLISS AVE N"
#   },
#   {
#     "longitude": "-122.33090541",
#     "value": "244158",
#     "issue_date": "2015-12-18T00:00:00",
#     "application_permit_number": "6480719",
#     "action_type": "NEW",
#     "latitude": "47.66061633",
#     "category": "MULTIFAMILY",
#     "address": "4406 CORLISS AVE N"
#   },
#   {
#     "longitude": "-122.32378355",
#     "value": "32080733",
#     "issue_date": "2015-12-11T00:00:00",
#     "application_permit_number": "6449319",
#     "action_type": "NEW",
#     "latitude": "47.60399886",
#     "category": "MULTIFAMILY",
#     "address": "3230 16TH AVE W"
#   },
#   {
#     "longitude": "-122.37490428",
#     "value": "45000",
#     "issue_date": "2015-12-10T00:00:00",
#     "application_permit_number": "6508074",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67257933",
#     "category": "MULTIFAMILY",
#     "address": "1426 NW 60TH ST"
#   },
#   {
#     "longitude": "-122.34513022",
#     "value": "100000",
#     "issue_date": "2015-12-10T00:00:00",
#     "application_permit_number": "6509015",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61227955",
#     "category": "MULTIFAMILY",
#     "address": "2125 1ST AVE"
#   },
#   {
#     "longitude": "-122.31980561",
#     "value": "75000",
#     "issue_date": "2015-12-09T00:00:00",
#     "application_permit_number": "6484028",
#     "action_type": "ADD/ALT",
#     "latitude": "47.60555723",
#     "category": "MULTIFAMILY",
#     "address": "411 10TH AVE"
#   },
#   {
#     "longitude": "-122.34525345",
#     "value": "15000",
#     "issue_date": "2015-12-09T00:00:00",
#     "application_permit_number": "6486923",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61779210",
#     "category": "MULTIFAMILY",
#     "address": "500 WALL ST"
#   },
#   {
#     "longitude": "-122.34645552",
#     "value": "566477",
#     "issue_date": "2015-12-09T00:00:00",
#     "application_permit_number": "6480515",
#     "action_type": "NEW",
#     "latitude": "47.65885512",
#     "category": "MULTIFAMILY",
#     "address": "4252 WINSLOW PL N"
#   },
#   {
#     "longitude": "-122.35581082",
#     "value": "123000",
#     "issue_date": "2015-12-07T00:00:00",
#     "application_permit_number": "6470170",
#     "action_type": "ADD/ALT",
#     "latitude": "47.70008106",
#     "category": "MULTIFAMILY",
#     "address": "9711 GREENWOOD AVE N"
#   },
#   {
#     "longitude": "-122.36790837",
#     "value": "789104",
#     "issue_date": "2015-12-07T00:00:00",
#     "application_permit_number": "6361974",
#     "action_type": "NEW",
#     "latitude": "47.53815731",
#     "category": "MULTIFAMILY",
#     "address": "7145 27TH AVE SW"
#   },
#   {
#     "longitude": "-122.36804674",
#     "value": "789104",
#     "issue_date": "2015-12-07T00:00:00",
#     "application_permit_number": "6361973",
#     "action_type": "NEW",
#     "latitude": "47.53851306",
#     "category": "MULTIFAMILY",
#     "address": "7127 27TH AVE SW"
#   },
#   {
#     "longitude": "-122.36797483",
#     "value": "705382",
#     "issue_date": "2015-12-07T00:00:00",
#     "application_permit_number": "6361970",
#     "action_type": "NEW",
#     "latitude": "47.53831287",
#     "category": "MULTIFAMILY",
#     "address": "7137 27TH AVE SW"
#   },
#   {
#     "longitude": "-122.26952102",
#     "value": "40000",
#     "issue_date": "2015-12-02T00:00:00",
#     "application_permit_number": "6507643",
# ...
#   },
#   {
#     "longitude": "-122.37795191",
#     "value": "2500",
#     "issue_date": "2011-09-13T00:00:00",
#     "application_permit_number": "6289042",
#     "action_type": "ADD/ALT",
#     "latitude": "47.57297915",
#     "category": "MULTIFAMILY",
#     "address": "3400 37TH AVE SW"
#   },
#   {
#     "longitude": "-122.32365087",
#     "value": "120000",
#     "issue_date": "2011-09-12T00:00:00",
#     "application_permit_number": "6288048",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63016813",
#     "category": "MULTIFAMILY",
#     "address": "640 32ND AVE E"
#   },
#   {
#     "longitude": "-122.33352832",
#     "value": "76000",
#     "issue_date": "2011-09-09T00:00:00",
#     "application_permit_number": "6295125",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61397452",
#     "category": "MULTIFAMILY",
#     "address": "809 OLIVE WAY"
#   },
#   {
#     "longitude": "-122.32692429",
#     "value": "8363105",
#     "issue_date": "2011-09-07T00:00:00",
#     "application_permit_number": "6213875",
#     "action_type": "NEW",
#     "latitude": "47.62543165",
#     "category": "MULTIFAMILY",
#     "address": "711 BELLEVUE AVE E"
#   },
#   {
#     "longitude": "-122.29317606",
#     "value": "15000",
#     "issue_date": "2011-08-31T00:00:00",
#     "application_permit_number": "6289805",
#     "action_type": "ADD/ALT",
#     "latitude": "47.57433895",
#     "category": "MULTIFAMILY",
#     "address": "3300 WETMORE AVE S"
#   },
#   {
#     "longitude": "-122.32933488",
#     "value": "79000",
#     "issue_date": "2011-08-26T00:00:00",
#     "application_permit_number": "6293828",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61089077",
#     "category": "MULTIFAMILY",
#     "address": "900 UNIVERSITY ST"
#   },
#   {
#     "longitude": "-122.31162516",
#     "value": "150000",
#     "issue_date": "2011-08-24T00:00:00",
#     "application_permit_number": "6284323",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62426174",
#     "category": "MULTIFAMILY",
#     "address": "535 16TH AVE E"
#   },
#   {
#     "longitude": "-122.34957979",
#     "value": "742970",
#     "issue_date": "2011-08-24T00:00:00",
#     "application_permit_number": "6264991",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61424902",
#     "category": "MULTIFAMILY",
#     "address": "2504 WESTERN AVE"
#   },
#   {
#     "longitude": "-122.34891948",
#     "value": "1442235",
#     "issue_date": "2011-08-24T00:00:00",
#     "application_permit_number": "6264992",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61386890",
#     "category": "MULTIFAMILY",
#     "address": "2440 WESTERN AVE"
#   },
#   {
#     "longitude": "-122.37523531",
#     "value": "37000",
#     "issue_date": "2011-08-19T00:00:00",
#     "application_permit_number": "6285157",
#     "action_type": "ADD/ALT",
#     "latitude": "47.65064605",
#     "category": "MULTIFAMILY",
#     "address": "3407 14TH AVE W"
#   },
#   {
#     "longitude": "-122.32734946",
#     "value": "4000",
#     "issue_date": "2011-08-18T00:00:00",
#     "application_permit_number": "6283976",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62769014",
#     "category": "MULTIFAMILY",
#     "address": "1027 BELLEVUE CT E"
#   },
#   {
#     "longitude": "-122.29693458",
#     "value": "4000",
#     "issue_date": "2011-08-18T00:00:00",
#     "application_permit_number": "6281501",
#     "action_type": "ADD/ALT",
#     "latitude": "47.59308896",
#     "category": "MULTIFAMILY",
#     "address": "2717 S NORMAN ST"
#   },
#   {
#     "longitude": "-122.35739732",
#     "value": "6131929",
#     "issue_date": "2011-08-15T00:00:00",
#     "application_permit_number": "6258969",
#     "action_type": "NEW",
#     "latitude": "47.63662870",
#     "category": "MULTIFAMILY",
#     "address": "1919 QUEEN ANNE AVE N"
#   },
#   {
#     "longitude": "-122.32607834",
#     "value": "75000",
#     "issue_date": "2011-08-10T00:00:00",
#     "application_permit_number": "6282468",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62764043",
#     "category": "MULTIFAMILY",
#     "address": "1012 BELMONT AVE E"
#   },
#   {
#     "longitude": "-122.28580136",
#     "value": "12517658",
#     "issue_date": "2011-08-03T00:00:00",
#     "application_permit_number": "6255925",
#     "action_type": "NEW",
#     "latitude": "47.55681585",
#     "category": "MULTIFAMILY",
#     "address": "3701 S HUDSON ST"
#   },
#   {
#     "longitude": "-122.27332298",
#     "value": "439692",
#     "issue_date": "2011-08-01T00:00:00",
#     "application_permit_number": "6176772",
#     "action_type": "NEW",
#     "latitude": "47.52258945",
#     "category": "MULTIFAMILY",
#     "address": "4624 S DIRECTOR ST"
#   },
#   {
#     "longitude": "-122.27312488",
#     "value": "413976",
#     "issue_date": "2011-08-01T00:00:00",
#     "application_permit_number": "6222233",
#     "action_type": "NEW",
#     "latitude": "47.52266884",
#     "category": "MULTIFAMILY",
#     "address": "9041 48TH AVE S"
#   },
#   {
#     "longitude": "-122.27313361",
#     "value": "296299",
#     "issue_date": "2011-08-01T00:00:00",
#     "application_permit_number": "6222231",
#     "action_type": "NEW",
#     "latitude": "47.52250141",
#     "category": "MULTIFAMILY",
#     "address": "4630 S DIRECTOR ST"
#   },
#   {
#     "longitude": "-122.27341866",
#     "value": "276978",
#     "issue_date": "2011-08-01T00:00:00",
#     "application_permit_number": "6222232",
#     "action_type": "NEW",
#     "latitude": "47.52266964",
#     "category": "MULTIFAMILY",
#     "address": "9047 48TH AVE S"
#   },
#   {
#     "longitude": "-122.34755185",
#     "value": "11654",
#     "issue_date": "2011-07-29T00:00:00",
#     "application_permit_number": "6221154",
#     "action_type": "ADD/ALT",
#     "latitude": "47.63422822",
#     "category": "MULTIFAMILY",
#     "address": "1717 5TH AVE N"
#   },
#   {
#     "longitude": "-122.37795191",
#     "value": "4000",
#     "issue_date": "2011-07-28T00:00:00",
#     "application_permit_number": "6290730",
#     "action_type": "ADD/ALT",
#     "latitude": "47.57297915",
#     "category": "MULTIFAMILY",
#     "address": "3400 37TH AVE SW"
#   },
#   {
#     "longitude": "-122.33927313",
#     "value": "6000",
#     "issue_date": "2011-07-26T00:00:00",
#     "application_permit_number": "6290405",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61296669",
#     "category": "MULTIFAMILY",
#     "address": "1920 4TH AVE"
#   },
#   {
#     "longitude": "-122.31734902",
#     "value": "3000",
#     "issue_date": "2011-07-21T00:00:00",
#     "application_permit_number": "6290113",
#     "action_type": "ADD/ALT",
#     "latitude": "47.65447918",
#     "category": "MULTIFAMILY",
#     "address": "2620 E CHERRY ST"
#   },
#   {
#     "longitude": "-122.31645531",
#     "value": "31154",
#     "issue_date": "2011-07-21T00:00:00",
#     "application_permit_number": "6284734",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62501977",
#     "category": "MULTIFAMILY",
#     "address": "624 12TH AVE E"
#   },
#   {
#     "longitude": "-122.28374911",
#     "value": "3000",
#     "issue_date": "2011-07-20T00:00:00",
#     "application_permit_number": "6289889",
#     "action_type": "ADD/ALT",
#     "latitude": "47.55531959",
#     "category": "MULTIFAMILY",
#     "address": "5205 39TH AVE S"
#   },
#   {
#     "longitude": "-122.32489014",
#     "value": "27114",
#     "issue_date": "2011-07-20T00:00:00",
#     "application_permit_number": "6285061",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61618664",
#     "category": "MULTIFAMILY",
#     "address": "1631 BELMONT AVE"
#   },
#   {
#     "longitude": "-122.35392325",
#     "value": "314926",
#     "issue_date": "2011-07-20T00:00:00",
#     "application_permit_number": "6285415",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62660584",
#     "category": "MULTIFAMILY",
#     "address": "150 VALLEY ST"
#   },
#   {
#     "longitude": "-122.28665026",
#     "value": "33000",
#     "issue_date": "2011-07-20T00:00:00",
#     "application_permit_number": "6276010",
#     "action_type": "ADD/ALT",
#     "latitude": "47.66208426",
#     "category": "MULTIFAMILY",
#     "address": "4545 SAND POINT WAY NE"
#   },
#   {
#     "longitude": "-122.37921355",
#     "value": "973893",
#     "issue_date": "2011-07-19T00:00:00",
#     "application_permit_number": "6287225",
#     "action_type": "ADD/ALT",
#     "latitude": "47.58729790",
#     "category": "MULTIFAMILY",
#     "address": "1727 HARBOR AVE SW"
#   },
#   {
#     "longitude": "-122.32012850",
#     "value": "54000",
#     "issue_date": "2011-07-15T00:00:00",
#     "application_permit_number": "6283014",
#     "action_type": "ADD/ALT",
#     "latitude": "47.66001470",
#     "category": "MULTIFAMILY",
#     "address": "4317 8TH AVE NE"
#   },
#   {
#     "longitude": "-122.32012519",
#     "value": "54000",
#     "issue_date": "2011-07-15T00:00:00",
#     "application_permit_number": "6287303",
#     "action_type": "ADD/ALT",
#     "latitude": "47.66037822",
#     "category": "MULTIFAMILY",
#     "address": "4327 8TH AVE NE"
#   },
#   {
#     "longitude": "-122.32012519",
#     "value": "54000",
#     "issue_date": "2011-07-15T00:00:00",
#     "application_permit_number": "6287304",
#     "action_type": "ADD/ALT",
#     "latitude": "47.66037822",
#     "category": "MULTIFAMILY",
#     "address": "4337 8TH AVE NE"
#   },
#   {
#     "longitude": "-122.31783228",
#     "value": "295844",
#     "issue_date": "2011-07-11T00:00:00",
#     "application_permit_number": "6287523",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61778446",
#     "category": "MULTIFAMILY",
#     "address": "1106 E HOWELL ST"
#   },
#   {
#     "longitude": "-122.29525819",
#     "value": "8000",
#     "issue_date": "2011-07-01T00:00:00",
#     "application_permit_number": "6287535",
#     "action_type": "ADD/ALT",
#     "latitude": "47.59188003",
#     "category": "MULTIFAMILY",
#     "address": "1306 29TH AVE S"
#   },
#   {
#     "longitude": "-122.35649154",
#     "value": "10000",
#     "issue_date": "2011-06-29T00:00:00",
#     "application_permit_number": "6280055",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62749394",
#     "category": "MULTIFAMILY",
#     "address": "900 QUEEN ANNE AVE N"
#   },
#   {
#     "longitude": "-122.34837693",
#     "value": "786918",
#     "issue_date": "2011-06-28T00:00:00",
#     "application_permit_number": "6270803",
#     "action_type": "NEW",
#     "latitude": "47.66371672",
#     "category": "MULTIFAMILY",
#     "address": "804 N 48TH ST"
#   },
#   {
#     "longitude": "-122.33611689",
#     "value": "50000",
#     "issue_date": "2011-06-23T00:00:00",
#     "application_permit_number": "6287229",
#     "action_type": "ADD/ALT",
#     "latitude": "47.60505522",
#     "category": "MULTIFAMILY",
#     "address": "1000 1ST AVE"
#   },
#   {
#     "longitude": "-122.35427142",
#     "value": "40000",
#     "issue_date": "2011-06-21T00:00:00",
#     "application_permit_number": "6286874",
#     "action_type": "ADD/ALT",
#     "latitude": "47.72650211",
#     "category": "MULTIFAMILY",
#     "address": "322 N 134TH ST"
#   },
#   {
#     "longitude": "-122.31184531",
#     "value": "4000",
#     "issue_date": "2011-06-21T00:00:00",
#     "application_permit_number": "6286171",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62250064",
#     "category": "MULTIFAMILY",
#     "address": "403 16TH AVE E"
#   },
#   {
#     "longitude": "-122.39313380",
#     "value": "75000",
#     "issue_date": "2011-06-14T00:00:00",
#     "application_permit_number": "6286225",
#     "action_type": "ADD/ALT",
#     "latitude": "47.58998685",
#     "category": "MULTIFAMILY",
#     "address": "1526 ALKI AVE SW"
#   },
#   {
#     "longitude": "-122.34523193",
#     "value": "30000",
#     "issue_date": "2011-06-10T00:00:00",
#     "application_permit_number": "6285900",
#     "action_type": "ADD/ALT",
#     "latitude": "47.69306533",
#     "category": "MULTIFAMILY",
#     "address": "8801 AURORA AVE N"
#   },
#   {
#     "longitude": "-122.32708613",
#     "value": "46000",
#     "issue_date": "2011-06-10T00:00:00",
#     "application_permit_number": "6285883",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62249180",
#     "category": "MULTIFAMILY",
#     "address": "421 BELLEVUE AVE E"
#   },
#   {
#     "longitude": "-122.32602933",
#     "value": "15000",
#     "issue_date": "2011-06-10T00:00:00",
#     "application_permit_number": "6285874",
#     "action_type": "ADD/ALT",
#     "latitude": "47.62879596",
#     "category": "MULTIFAMILY",
#     "address": "1028 LAKEVIEW BLVD E"
#   },
#   {
#     "longitude": "-122.28255501",
#     "value": "20000",
#     "issue_date": "2011-06-10T00:00:00",
#     "application_permit_number": "6285849",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67841087",
#     "category": "MULTIFAMILY",
#     "address": "6825 43RD AVE NE"
#   },
#   {
#     "longitude": "-122.28673926",
#     "value": "231177",
#     "issue_date": "2011-06-10T00:00:00",
#     "application_permit_number": "6283663",
#     "action_type": "ADD/ALT",
#     "latitude": "47.59743109",
#     "category": "MULTIFAMILY",
#     "address": "510 LAKESIDE AVE S"
#   },
#   {
#     "longitude": "-122.34902993",
#     "value": "125000",
#     "issue_date": "2011-06-06T00:00:00",
#     "application_permit_number": "6285286",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61754703",
#     "category": "MULTIFAMILY",
#     "address": "2720 3RD AVE"
#   },
#   {
#     "longitude": "-122.31044878",
#     "value": "100000",
#     "issue_date": "2011-06-03T00:00:00",
#     "application_permit_number": "6272017",
#     "action_type": "ADD/ALT",
#     "latitude": "47.61455577",
#     "category": "MULTIFAMILY",
#     "address": "1501 17TH AVE"
#   },
#   {
#     "longitude": "-122.37790303",
#     "value": "283133",
#     "issue_date": "2011-06-03T00:00:00",
#     "application_permit_number": "6265218",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67545968",
#     "category": "MULTIFAMILY",
#     "address": "1536 NW 64TH ST"
#   },
#   {
#     "longitude": "-122.31267151",
#     "value": "25000",
#     "issue_date": "2011-06-01T00:00:00",
#     "application_permit_number": "6284866",
#     "action_type": "ADD/ALT",
#     "latitude": "47.66321856",
#     "category": "MULTIFAMILY",
#     "address": "4710 UNIVERSITY WAY NE"
#   },
#   {
#     "longitude": "-122.31524783",
#     "value": "391316",
#     "issue_date": "2011-05-27T00:00:00",
#     "application_permit_number": "6230470",
#     "action_type": "NEW",
#     "latitude": "47.62013550",
#     "category": "MULTIFAMILY",
#     "address": "15 ROY ST"
#   },
#   {
#     "longitude": "-122.31531516",
#     "value": "555695",
#     "issue_date": "2011-05-27T00:00:00",
#     "application_permit_number": "6266965",
#     "action_type": "NEW",
#     "latitude": "47.62028071",
#     "category": "MULTIFAMILY",
#     "address": "208 13TH AVE E"
#   },
#   {
#     "longitude": "-122.38920402",
#     "value": "1000",
#     "issue_date": "2011-05-25T00:00:00",
#     "application_permit_number": "6284382",
#     "action_type": "ADD/ALT",
#     "latitude": "47.56194875",
#     "category": "MULTIFAMILY",
#     "address": "4517 GLENN WAY SW"
#   },
#   {
#     "longitude": "-122.35729520",
#     "value": "1000",
#     "issue_date": "2011-05-25T00:00:00",
#     "application_permit_number": "6277142",
#     "action_type": "NEW",
#     "latitude": "47.63627759",
#     "category": "MULTIFAMILY",
#     "address": "1905 QUEEN ANNE AVE N"
#   },
#   {
#     "longitude": "-122.35739732",
#     "value": "100000",
#     "issue_date": "2011-05-25T00:00:00",
#     "application_permit_number": "6272314",
#     "action_type": "NEW",
#     "latitude": "47.63662870",
#     "category": "MULTIFAMILY",
#     "address": "1919 QUEEN ANNE AVE N"
#   },
#   {
#     "longitude": "-122.32157708",
#     "value": "8500",
#     "issue_date": "2011-05-23T00:00:00",
#     "application_permit_number": "6283809",
#     "action_type": "ADD/ALT",
#     "latitude": "47.70978696",
#     "category": "MULTIFAMILY",
#     "address": "11045 8TH AVE NE"
#   },
#   {
#     "longitude": "-122.36268879",
#     "value": "49604",
#     "issue_date": "2011-05-20T00:00:00",
#     "application_permit_number": "6283951",
#     "action_type": "ADD/ALT",
#     "latitude": "47.53332230",
#     "category": "MULTIFAMILY",
#     "address": "2201 SW HOLDEN ST"
#   },
#   {
#     "longitude": "-122.32201451",
#     "value": "60000",
#     "issue_date": "2011-05-20T00:00:00",
#     "application_permit_number": "6283932",
#     "action_type": "ADD/ALT",
#     "latitude": "47.67930699",
#     "category": "MULTIFAMILY",
#     "address": "505 NE 70TH ST"
#   },
#   {
#     "longitude": "-122.28649950",
#     "value": "20000",
#     "issue_date": "2011-05-19T00:00:00",
#     "application_permit_number": "6283798",
#     "action_type": "ADD/ALT",
#     "latitude": "47.56363437",
#     "category": "MULTIFAMILY",
#     "address": "4420 36TH AVE S"
#   }
# ]

# %%
#save the JSON object as a file as well, just in case we lose access to the API later
with open('permits_by_neighborhood_2010-2016_1228.json', 'w') as json_outfile:
    json.dump(permits_by_neighborhood, json_outfile)

# %%
from dateutil import parser
for x in bp_api_data:
    x['issue_datetime'] = parser.parse(x['issue_date'])

print(bp_api_data[875])
print(bp_api_data[875]['issue_datetime'].year)
# Out:
# {'longitude': '-122.32756652', 'value': '20000', 'issue_date': '2013-10-08T00:00:00', 'application_permit_number': '6386469', 'issue_datetime': datetime.datetime(2013, 10, 8, 0, 0), 'action_type': 'ADD/ALT', 'latitude': '47.62332368', 'category': 'MULTIFAMILY', 'address': '308 E REPUBLICAN ST'}
# 2013

# %%
import datetime
oldest_record = datetime.datetime.today()

for x in bp_api_data:
    if x['issue_datetime'] < oldest_record:
        oldest_record = x['issue_datetime']

print("The oldest record in our dataset is from %s" % (oldest_record.strftime("%m/%d/%Y")))

newest_record = oldest_record
for x in bp_api_data:
    if x['issue_datetime'] > newest_record:
        newest_record = x['issue_datetime']

print("The newest record in our dataset is from %s" % (newest_record.strftime("%m/%d/%Y")))
# Out:
# The oldest record in our dataset is from 05/19/2011
# The newest record in our dataset is from 05/13/2016
